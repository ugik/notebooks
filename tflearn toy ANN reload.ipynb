# %%
import numpy as np
import tflearn
# Build neural network
net = tflearn.input_data(shape=[None, 5])
net = tflearn.fully_connected(net, 32)
net = tflearn.fully_connected(net, 32)
net = tflearn.fully_connected(net, 2, activation='softmax')
net = tflearn.regression(net)

# Define model
model = tflearn.DNN(net)
# Load model 
model.load('ANN.model')
# Out:
# -------------------------------------------------------------------------
# NotFoundError                           Traceback (most recent call last)
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# NotFoundError: Key FullyConnected_26/b/Adam not found in checkpoint
# 	 [[Node: save_25/RestoreV2_218 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_25/Const_0, save_25/RestoreV2_218/tensor_names, save_25/RestoreV2_218/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                           Traceback (most recent call last)
# <ipython-input-9-65cd72d4882f> in <module>()
#      11 model = tflearn.DNN(net)
#      12 # Load model
# ---> 13 model.load('ANN.model')
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tflearn/models/dnn.py in load(self, model_file, weights_only, **optargs)
#     276                      created for the restored variables.
#     277         """
# --> 278         self.trainer.restore(model_file, weights_only, **optargs)
#     279         self.session = self.trainer.session
#     280         self.predictor = Evaluator([self.net],
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tflearn/helpers/trainer.py in restore(self, model_file, trainable_variable_only, variable_name_map, scope_for_restore, create_new_session, verbose)
#     447             restorer.restore(self.session, model_file)
#     448         elif not trainable_variable_only:
# --> 449             self.restorer.restore(self.session, model_file)
#     450         else:
#     451             self.restorer_trainvars.restore(self.session, model_file)
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1426       return
#    1427     sess.run(self.saver_def.restore_op_name,
# -> 1428              {self.saver_def.filename_tensor_name: save_path})
#    1429
#    1430   @staticmethod
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: Key FullyConnected_26/b/Adam not found in checkpoint
# 	 [[Node: save_25/RestoreV2_218 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_25/Const_0, save_25/RestoreV2_218/tensor_names, save_25/RestoreV2_218/shape_and_slices)]]
#
# Caused by op 'save_25/RestoreV2_218', defined at:
#   File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-65cd72d4882f>", line 11, in <module>
#     model = tflearn.DNN(net)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tflearn/models/dnn.py", line 64, in __init__
#     best_val_accuracy=best_val_accuracy)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tflearn/helpers/trainer.py", line 145, in __init__
#     keep_checkpoint_every_n_hours=keep_checkpoint_every_n_hours)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1040, in __init__
#     self.build()
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1070, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 402, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 242, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 668, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/gk/.virtualenvs/BotStructures/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key FullyConnected_26/b/Adam not found in checkpoint
# 	 [[Node: save_25/RestoreV2_218 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_25/Const_0, save_25/RestoreV2_218/tensor_names, save_25/RestoreV2_218/shape_and_slices)]]
